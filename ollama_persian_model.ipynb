# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahsun1366/Meter/blob/MPRev/ollama_persian_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !curl https://ollama.ai/install.sh | sh

# !echo 'debconf debconf/frontend select Noninteractive' | sudo debconf-set-selections
#!sudo apt-get update && sudo apt-get install -y cuda-drivers

import os

# Set LD_LIBRARY_PATH so the system NVIDIA library
#os.environ.update({'LD_LIBRARY_PATH': '/usr/lib64-nvidia'})

# %%
# start server
# !nohup ollama serve &
# Out:
# nohup: appending output to 'nohup.out'

# %%
# pull deepseek-r1:32b
# !ollama pull partai/dorna-llama3:latest

# %%
# !pip install ollama

# %%
import ollama
response = ollama.chat(model='mshojaei77/gemma3persian:latest', messages=[
  {
    'role': 'user',
    'content': "آیا می‌توانی هم‌زمان مزایا و معایب انرژی هسته‌ای را توضیح دهی و آن را با انرژی تجدیدپذیر مقایسه کنی؟"
  },
])
print(response['message']['content'])
# Out:
# البته، حتماً. انرژی هسته‌ای و انرژی تجدیدپذیر هر دو به عنوان راه‌حل‌های مهم برای مقابله با تغییرات اقلیمی و تامین انرژی آینده مطرح هستند، اما هر کدام مزایا و معایب خاص خود را دارند.
#
# **انرژی هسته‌ای:**
#
# *   **مزایا:**
#     *   **تولید برق پایدار:** نیروگاه‌های هسته‌ای می‌توانند به طور مداوم برق تولید کنند و وابستگی به شرایط آب و هوایی مانند خورشید یا باد را ندارند.
#     *   **تولید برق با کمترین انتشار گازهای گلخانه‌ای:** در طول چرخه تولید برق، نیروگاه‌های هسته‌ای تقریباً هیچ گاز گلخانه‌ای منتشر نمی‌کنند.
#     *   **تولید برق پرقدرت:** نیروگاه‌های هسته‌ای می‌توانند مقدار زیادی برق تولید کنند و به عنوان یک منبع اصلی انرژی در شبکه‌های برق کشورها عمل کنند.
# *   **معایب:**
#     *   **خطر وقوع حادثه:** وقوع حادثه هسته‌ای مانند چرنوبیل یا فوکوشیما می‌تواند عواقب فاجعه‌باری برای محیط زیست و سلامت انسان داشته باشد.
#     *   **مدیریت زباله‌های هسته‌ای:** زباله‌های هسته‌ای برای هزاران سال رادیواکتیو باقی می‌مانند و نیاز به مدیریت و نگهداری ویژه دارند.
# ...
